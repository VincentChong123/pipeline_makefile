# %%
# !pip install -q nbformat nbconvert

# %%
from  datetime import datetime
start = datetime.now()
start
# Out:
# datetime.datetime(2024, 8, 18, 18, 23, 51, 990310)

# %%
import matplotlib.pyplot as plt

# Your plotting code
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Sample Plot")
plt.savefig('plot.png')  # Save the plot as an image

# %%
from  datetime import datetime
end = datetime.now()
total_exec_time = end - start

# !echo start $start > "../log/auto.log"
# !echo end $end >> "../log/auto.log"
# !echo total execution time $total_exec_time sec >> "../log/auto.log"
